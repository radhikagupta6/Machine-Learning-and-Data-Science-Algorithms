# %%
import pandas as pd
import numpy as np

# %% [markdown]
# pandas objects are--- series object, DataFrame object
# objects can hold any type of values.
# here 1D list is known as : Series

# %%
list=[20,19,20,19,18,23,22,23,24,19,20,25]
a=np.array(list)
s=pd.Series(list)

# %%
s
# Out:
# 0     20
# 1     19
# 2     20
# 3     19
# 4     18
# 5     23
# 6     22
# 7     23
# 8     24
# 9     19
# 10    20
# 11    25
# dtype: int64

# %%
np.unique(a)
# Out:
# array([18, 19, 20, 22, 23, 24, 25])

# %%
s.unique()
# Out:
# array([20, 19, 18, 23, 22, 24, 25], dtype=int64)

# %%
s.mode()  #for calculating the mode of the array
# Out:
# 0    19
# 1    20
# dtype: int64

# %%
#Creating a DataFrame
df=pd.DataFrame([['A',10,5],['B',11,3],['C',14,2]])

# %%
df
# Out:
#    0   1  2
# 0  A  10  5
# 1  B  11  3
# 2  C  14  2

# %%
df=pd.DataFrame([['A',10,5],['B',11,3],['C',14,2]],columns=['name','age','roll no.'],index=['r1','r2','r3'])  #([2D list], columns=['l1','l2'], index(for row label)= ['l1','l2'])

# %%
df
# Out:
#    name  age  roll no.
# r1    A   10         5
# r2    B   11         3
# r3    C   14         2

# %%
df=pd.DataFrame({'name':['P','Q','R'],'my age':[10,11,12],'roll no.':[67,75,58]})

# %%
#x=df.name

# %%
#type(x)
# Out:
# pandas.core.series.Series

# %%
df['name']
# Out:
# 0    P
# 1    Q
# 2    R
# Name: name, dtype: object

# %%
df['my age']                          #df.my age   this won't be accepted
# Out:
# 0    10
# 1    11
# 2    12
# Name: my age, dtype: int64

# %%
df['marks']=[600,500,650]

# %%
df
# Out:
#   name  my age  roll no.  marks
# 0    P      10        67    600
# 1    Q      11        75    500
# 2    R      12        58    650

# %%
df['name']=['Radhika','varnika','Kaavya']

# %%
df
# Out:
#       name  my age  roll no.  marks
# 0  Radhika      10        67    600
# 1  varnika      11        75    500
# 2   Kaavya      12        58    650

# %%
df.insert(0,'clg',['Gbu','Gbu','Gbu'])

# %%
df
# Out:
#    clg     name  my age  roll no.  marks
# 0  Gbu  Radhika      10        67    600
# 1  Gbu  varnika      11        75    500
# 2  Gbu   Kaavya      12        58    650

# %%
df.drop('my age', axis=1)  #not changing actual
# Out:
#    clg     name  roll no.  marks
# 0  Gbu  Radhika        67    600
# 1  Gbu  varnika        75    500
# 2  Gbu   Kaavya        58    650

# %%
df
# Out:
#    clg     name  my age  roll no.  marks
# 0  Gbu  Radhika      10        67    600
# 1  Gbu  varnika      11        75    500
# 2  Gbu   Kaavya      12        58    650

# %%
df.drop('my age', axis=1, inplace=True) #changing actually

# %%
df
# Out:
#    clg     name  roll no.  marks
# 0  Gbu  Radhika        67    600
# 1  Gbu  varnika        75    500
# 2  Gbu   Kaavya        58    650

# %%
df.drop(1,axis=0)
# Out:
#    clg     name  roll no.  marks
# 0  Gbu  Radhika        67    600
# 2  Gbu   Kaavya        58    650

# %%
df
# Out:
#    clg     name  roll no.  marks
# 0  Gbu  Radhika        67    600
# 1  Gbu  varnika        75    500
# 2  Gbu   Kaavya        58    650

# %% [markdown]
# 12 june

# %%
df.rename({'name':'sname'}, axis=1)  #changes in copy
# Out:
#    clg    sname  roll no.  marks
# 0  Gbu  Radhika        67    600
# 1  Gbu  varnika        75    500
# 2  Gbu   Kaavya        58    650

# %%
df.rename({0:'a',1:'b'}, axis=0, inplace=True)

# %%
df.reindex(['sname','roll no.','marks','clg'], axis=1)  #rearrages the column according to us
# Out:
#    sname  roll no.  marks  clg
# a    NaN        67    600  Gbu
# b    NaN        75    500  Gbu
# 2    NaN        58    650  Gbu

# %%
#add row to existing datafram.....loc-labelled loaction
df.loc['z']=['sachin',900,39,'india']

# %%
df
# Out:
#       clg     name  roll no.  marks
# a     Gbu  Radhika        67    600
# b     Gbu  varnika        75    500
# 2     Gbu   Kaavya        58    650
# z  sachin      900        39  india

# %%
df.at['x']=['viru',800,34,'c4']  #faster than loc

# %%
df
# Out:
#       clg     name  roll no.  marks
# a     Gbu  Radhika      67.0    600
# b     Gbu  varnika      75.0    500
# 2     Gbu   Kaavya      58.0    650
# z  sachin      900      39.0  india
# x    viru      800      34.0     c4

# %%
df.iloc[0]=['c5','pandya',33,400]  # iloc works on existing index

# %%
df
# Out:
#       clg     name  roll no.  marks
# a      c5   pandya      33.0    400
# b     Gbu  varnika      75.0    500
# 2     Gbu   Kaavya      58.0    650
# z  sachin      900      39.0  india
# x    viru      800      34.0     c4

# %%
df.loc['z']=['c6','sachin',39,900]

# %%
df
# Out:
#     clg     name  roll no. marks
# a    c5   pandya      33.0   400
# b   Gbu  varnika      75.0   500
# 2   Gbu   Kaavya      58.0   650
# z    c6   sachin      39.0   900
# x  viru      800      34.0    c4

# %%
df.loc['z','name']='radhika' # changes the value of the [i,j]th element

# %%
df
# Out:
#     clg     name  roll no. marks
# a    c5   pandya      33.0   400
# b   Gbu  varnika      75.0   500
# 2   Gbu   Kaavya      58.0   650
# z    c6  radhika      39.0   900
# x  viru      800      34.0    c4

# %%
df.at['x','clg']='amity'

# %%
df
# Out:
#      clg     name  roll no. marks
# a     c5   pandya      33.0   400
# b    Gbu  varnika      75.0   500
# 2    Gbu   Kaavya      58.0   650
# z     c6  radhika      39.0   900
# x  amity      800      34.0    c4

# %%
df.iloc[1,2]=37

# %%
df
# Out:
#      clg     name  roll no. marks
# a     c5   pandya      33.0   400
# b    Gbu  varnika      37.0   500
# 2    Gbu   Kaavya      58.0   650
# z     c6  radhika      39.0   900
# x  amity      800      34.0    c4

# %%
df.loc[2]
# Out:
# clg            Gbu
# name        Kaavya
# roll no.        58
# marks          650
# Name: 2, dtype: object

# %%
df.at[2,'name' ]
# Out:
# 'Kaavya'

# %%
df.iloc[3]   #gets particular row
# Out:
# clg              c6
# name        radhika
# roll no.         39
# marks           900
# Name: z, dtype: object

# %%
df
# Out:
#      clg     name  roll no. marks
# a     c5   pandya      33.0   400
# b    Gbu  varnika      37.0   500
# 2    Gbu   Kaavya      58.0   650
# z     c6  radhika      39.0   900
# x  amity      800      34.0    c4

# %%
df.head(3)  #gets the number of rows specified from up
# Out:
#    clg     name  roll no. marks
# a   c5   pandya      33.0   400
# b  Gbu  varnika      37.0   500
# 2  Gbu   Kaavya      58.0   650

# %%
df.tail(2)  #gets the number of rows specified from down
# Out:
#      clg     name  roll no. marks
# z     c6  radhika      39.0   900
# x  amity      800      34.0    c4

# %%
df.iloc[0::2,:]
# Out:
#      clg    name  roll no. marks
# a     c5  pandya      33.0   400
# 2    Gbu  Kaavya      58.0   650
# x  amity     800      34.0    c4

# %%
df
# Out:
#      clg     name  roll no. marks
# a     c5   pandya      33.0   400
# b    Gbu  varnika      37.0   500
# 2    Gbu   Kaavya      58.0   650
# z     c6  radhika      39.0   900
# x  amity      800      34.0    c4

# %%
df.iloc[:,:-1]  #exclusing the last column
# Out:
#      clg     name  roll no.
# a     c5   pandya      33.0
# b    Gbu  varnika      37.0
# 2    Gbu   Kaavya      58.0
# z     c6  radhika      39.0
# x  amity      800      34.0

# %%
df
# Out:
#      clg     name  roll no. marks
# a     c5   pandya      33.0   400
# b    Gbu  varnika      37.0   500
# 2    Gbu   Kaavya      58.0   650
# z     c6  radhika      39.0   900
# x  amity      800      34.0    c4

# %%
df.at['x','marks']=500

# %%
df.sort_values('marks')
# Out:
#      clg     name  roll no. marks
# a     c5   pandya      33.0   400
# b    Gbu  varnika      37.0   500
# x  amity      800      34.0   500
# 2    Gbu   Kaavya      58.0   650
# z     c6  radhika      39.0   900

# %%
df.sort_values('marks', ascending=False)
# Out:
#      clg     name  roll no. marks
# z     c6  radhika      39.0   900
# 2    Gbu   Kaavya      58.0   650
# b    Gbu  varnika      37.0   500
# x  amity      800      34.0   500
# a     c5   pandya      33.0   400

# %% [markdown]
# DataFrame ---can read data from any text file, excel file, JSON file, database, webpage, HDFS, url

# %%
df=pd.read_csv('tt.txt', header= None)
df
# Out:
#    0  1   2
# 0  a  1  20
# 1  b  2  21
# 2  c  3  18

# %%
df=pd.read_csv('tt.txt', names=['name','roll no.', 'marks'])   #for naming the columns....for tab separated values ----df=pd.read_csv('tt.txt',delimiter='\t',names=['name','roll no.', 'marks']) 
df
# Out:
#   name  roll no.  marks
# 0    a         1     20
# 1    b         2     21
# 2    c         3     18

# %% [markdown]
# Missing value is represented by NaN

# %%
df=pd.read_excel('dataset/movies_sheets.xls')

# %%
df.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#               Category Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# ...

# %%
df.shape
# Out:
# (1338, 25)

# %%
df.columns  #displays the list of columns
# Out:
# Index(['Title', 'Year', 'Category', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
#       dtype='object')

# %%
dff=df.loc[:,('Title', 'Year', 'Budget', 'Category','Duration','Actor 1', 'Actor 2', 'Actor 3','IMDB Score')]

# %%
dff.head()
# Out:
#                                                Title  Year     Budget  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916   385907.0
# 1                    Over the Hill to the Poorhouse   1920   100000.0
# 2                                    The Big Parade   1925   245000.0
# 3                                        Metropolis   1927  6000000.0
# 4                                     Pandora's Box   1929        NaN
#
#               Category  Duration        Actor 1          Actor 2  \
# 0    Drama|History|War       123   Lillian Gish        Mae Marsh
# 1          Crime|Drama       110   Stephen Carr   Johnnie Walker
# 2    Drama|Romance|War       151   John Gilbert     Renée Adorée
# 3         Drama|Sci-Fi       145  Brigitte Helm  Gustav Fröhlich
# 4  Crime|Drama|Romance       110  Louise Brooks  Francis Lederer
#
#               Actor 3  IMDB Score
# 0         Walter Long         8.0
# 1           Mary Carr         4.8
# 2        Claire Adams         8.3
# ...

# %%
dff.shape
# Out:
# (1338, 9)

# %%
dff.Budget.isnull().sum()    #calculates the sum of no. of missing values of the column
# Out:
# 57

# %%
dff.isnull().sum()           #calculates the sum of no. of missing values of all the columns
# Out:
# Title          0
# Year           0
# Budget        57
# Category       0
# Duration       0
# Actor 1        0
# Actor 2        0
# Actor 3        2
# IMDB Score     0
# dtype: int64

# %%
dff["IMDB Score"].min()
# Out:
# 2.3

# %%
dff["IMDB Score"].max()
# Out:
# 9.3

# %%
dff["IMDB Score"].mean()
# Out:
# 6.702167414050817

# %%
df2=dff[dff["IMDB Score"]>=dff["IMDB Score"].mean()]    #filtering rows having greater mean

# %%
df2
# Out:
#                                                   Title  Year      Budget  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916    385907.0
# 2                                       The Big Parade   1925    245000.0
# 3                                           Metropolis   1927   6000000.0
# 4                                        Pandora's Box   1929         NaN
# 6                                        Hell's Angels   1930   3950000.0
# 8                                          42nd Street   1933    439000.0
# 10                               It Happened One Night   1934    325000.0
# 11                                             Top Hat   1935    609000.0
# 12                                        Modern Times   1936   1500000.0
# 13                     The Charge of the Light Brigade   1936   1200000.0
# 14                     Snow White and the Seven Dwarfs   1937   2000000.0
# 15                               The Prisoner of Zenda   1937         NaN
# ...

# %%
df2.Budget.mean()
# Out:
# 24456644.214177977

# %%
df2.Category.value_counts()
# Out:
# Drama                                                    48
# Comedy|Drama                                             29
# Drama|Romance                                            27
# Crime|Drama                                              22
# Comedy                                                   22
# Comedy|Drama|Romance                                     20
# Action|Adventure|Thriller                                14
# Crime|Drama|Thriller                                     10
# Comedy|Romance                                            9
# Drama|Mystery|Thriller                                    8
# Drama|War                                                 7
# Western                                                   7
# Biography|Drama|History                                   7
# Drama|Romance|War                                         7
# Comedy|Crime                                              7
# Crime|Drama|Romance                                       6
# ...

# %%
df2.Duration.mean()
# Out:
# 119.90857142857143

# %%
#d1=pd.read_excel('dataset/movies_sheets.xls', sheet_name='2010s')
d1=pd.read_excel('dataset/movies_sheets.xls', sheet_name=2, nrows= 10, skiprows= 500, usecols=['English','USA'])

# %%
d1
# Out:
#    English     USA
# 0  English     USA
# 1  English      UK
# 2  English      UK
# 3  English     USA
# 4  English  Canada
# 5  English     USA
# 6   French  France
# 7  English     USA
# 8  English     USA
# 9  English     USA

# %%
df=pd.read_csv("dataset/titanic.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
dfs=df[df.Survived==1]

# %%
dfs.shape
# Out:
# (342, 12)

# %%
df.gender.value_counts()
# Out:
# male      577
# female    314
# Name: gender, dtype: int64

# %%
dfs.gender.value_counts()
# Out:
# female    233
# male      109
# Name: gender, dtype: int64

# %% [markdown]
# 13th June

# %%
dfs[(dfs.Age==10)|(dfs.Age==11)].shape
# Out:
# (1, 12)

# %%
dfs[(dfs.Age>=10)&(dfs.Age<11)].shape
# Out:
# (0, 12)

# %%
dfs[dfs.Age.isin([10,15,20,25])].shape
# Out:
# (13, 12)

# %%
dfs[dfs.Age.isin(range(10,31,1))].shape
# Out:
# (128, 12)

# %%
dfs.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  gender   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
#those who paid max fare did survive or not ?
df.Fare.value_counts()
df.Fare.max()
# Out:
# 512.3292

# %%
df[df.Fare==df.Fare.max()]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#      gender   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df[df.Fare==df.Fare.max()].Survived.value_counts()
# Out:
# 1    3
# Name: Survived, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#for converting the whole column to lower case....apply used for operations on the columns...apply calls the method for whole column
df['Name']=df.Name.apply(str.lower)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#for applying len() function to the whole column
df['name_length']=df.Name.apply(len)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  name_length
# 0      0         A/5 21171   7.2500   NaN        S           23
# 1      0          PC 17599  71.2833   C85        C           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S           22
# ...

# %%
#using map function... map can do the work of apply too... map me function or dictionary dono pass ho salte hain
df['gender']=df.gender.map({"male":1,"female":2})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            braund, mr. owen harris       1  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...       2  38.0      1
# 2                             heikkinen, miss. laina       2  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)       2  35.0      1
# 4                           allen, mr. william henry       1  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  name_length
# 0      0         A/5 21171   7.2500   NaN        S           23
# 1      0          PC 17599  71.2833   C85        C           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S           22
# ...
