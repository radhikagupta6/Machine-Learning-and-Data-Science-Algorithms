# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

# %%
my_url= 'https://www.flipkart.com/search?q=samsung+phone+under+15000&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_0_22&otracker1=AS_QueryStore_OrganicAutoSuggest_0_22&as-pos=0&as-type=RECENT&as-backfill=on'

# %%
uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()
page_soup = soup(page_html,'html.parser')
containers=page_soup.findAll("div",{"class":"_1UoZlX"})
#print(soup.prettify(containers[0]))
container=containers[0]
#print(container.div.img["alt"])
price=container.findAll("div",{"class":"col col-5-12 _2o7WAb"})
#print(price[0].text)
rating=container.findAll("div",{"class":"hGSR34"})
#print(ratings[0].text)

# %%
filename="products.csv"
f= open(filename,'w')

headers="prod_Name,Price,Ratings\n"
f.write(headers)

for container in containers:
    product_name = container.div.img["alt"]
    price_container=container.findAll("div",{"class":"col col-5-12 _2o7WAb"})
    price= price_container[0].text.strip()
    rating_container=container.findAll("div",{"class":"hGSR34"})
    rating = rating_container[0].text
    print("Product:" + product_name)
    print("price:" + price)
    print("ratings:" + rating)
    trim_price = ''.join(price.split(','))
    rm_rupee= trim_price.split("₹")
    add_rs_price="Rs." + rm_rupee[1]
    split_price = add_rs_price.split('E')
    final_price = split_price[0]
    split_rating = rating.split(" ")
    final_rating = split_rating[0]
    print(product_name.replace(",","|") + "," +final_price + "," +final_rating + "\n")
    f.write(product_name.replace(",","|") + "," +final_price + "," +final_rating + "\n")
f.close()
# Out:
# Product:Samsung Galaxy A20s (Blue, 32 GB)
# price:₹11,999₹12,9006% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.5
# Samsung Galaxy A20s (Blue| 32 GB),Rs.11999,4.5
#
# Product:Samsung Galaxy A20s (Black, 32 GB)
# price:₹11,999₹12,9006% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.5
# Samsung Galaxy A20s (Black| 32 GB),Rs.11999,4.5
#
# Product:Samsung Galaxy A20 (Black, 32 GB)
# price:₹11,490₹12,90010% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.3
# Samsung Galaxy A20 (Black| 32 GB),Rs.11490,4.3
#
# Product:Samsung Galaxy A30 (Black, 64 GB)
# price:₹15,490₹18,00013% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.4
# Samsung Galaxy A30 (Black| 64 GB),Rs.15490,4.4
#
# Product:Samsung Galaxy A30 (Blue, 64 GB)
# price:₹15,490₹18,00013% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.4
# Samsung Galaxy A30 (Blue| 64 GB),Rs.15490,4.4
#
# Product:Samsung Galaxy A20 (Gold, 32 GB)
# price:₹11,490₹12,90010% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.3
# Samsung Galaxy A20 (Gold| 32 GB),Rs.11490,4.3
#
# Product:Samsung Galaxy A10s (Green, 32 GB)
# price:₹10,499₹11,0004% offUpto ₹9,250 Off on Exchange
# ratings:4.5
# Samsung Galaxy A10s (Green| 32 GB),Rs.10499,4.5
#
# Product:Samsung Galaxy A20 (Deep Blue, 32 GB)
# price:₹11,490₹12,90010% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.3
# Samsung Galaxy A20 (Deep Blue| 32 GB),Rs.11490,4.3
#
# Product:Samsung Galaxy A10s (Black, 32 GB)
# price:₹10,499₹11,0004% offUpto ₹9,250 Off on Exchange
# ratings:4.5
# Samsung Galaxy A10s (Black| 32 GB),Rs.10499,4.5
#
# Product:Samsung Galaxy J6 (Blue, 64 GB)
# price:₹9,490₹12,90026% offNo Cost EMIUpto ₹9,250 Off on Exchange
# ratings:4.5
# Samsung Galaxy J6 (Blue| 64 GB),Rs.9490,4.5
#
# Product:Samsung Galaxy J6 (Black, 32 GB)
# price:₹10,490₹11,5008% offNo Cost EMIUpto ₹9,250 Off on Exchange
# ratings:4.4
# Samsung Galaxy J6 (Black| 32 GB),Rs.10490,4.4
#
# Product:Samsung Galaxy A30 (White, 64 GB)
# price:₹15,490₹18,00013% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.4
# Samsung Galaxy A30 (White| 64 GB),Rs.15490,4.4
#
# Product:Samsung Galaxy M30 (Gradation Blue, 64 GB)
# price:₹13,999₹16,49015% off
# ratings:4.4
# Samsung Galaxy M30 (Gradation Blue| 64 GB),Rs.13999,4.4
#
# Product:Samsung Galaxy A10s (Blue, 32 GB)
# price:₹9,499₹10,0005% offUpto ₹9,250 Off on Exchange
# ratings:4.4
# Samsung Galaxy A10s (Blue| 32 GB),Rs.9499,4.4
#
# Product:Samsung Galaxy J6 (Black, 64 GB)
# price:₹9,490₹12,90026% offNo Cost EMIUpto ₹9,250 Off on Exchange
# ratings:4.5
# Samsung Galaxy J6 (Black| 64 GB),Rs.9490,4.5
#
# Product:Samsung Galaxy J7 - 6 (New 2016 Edition) (Black, 16 GB)
# price:₹13,800No Cost EMI
# ratings:4.3
# Samsung Galaxy J7 - 6 (New 2016 Edition) (Black| 16 GB),Rs.13800No Cost ,4.3
#
# Product:Samsung Galaxy J4 (Black, 16 GB)
# price:₹9,600No Cost EMIUpto ₹9,250 Off on Exchange
# ratings:4.3
# Samsung Galaxy J4 (Black| 16 GB),Rs.9600No Cost ,4.3
#
# Product:Samsung On7 Pro (Gold, 16 GB)
# price:₹7,980₹9,49015% off
# ratings:4.1
# Samsung On7 Pro (Gold| 16 GB),Rs.7980,4.1
#
# Product:Samsung Galaxy J6 (Blue, 32 GB)
# price:₹10,490₹11,5008% offNo Cost EMIUpto ₹9,250 Off on Exchange
# ratings:4.4
# Samsung Galaxy J6 (Blue| 32 GB),Rs.10490,4.4
#
# Product:Samsung Galaxy J7 Prime (Gold, 32 GB)
# price:₹15,300No Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.2
# Samsung Galaxy J7 Prime (Gold| 32 GB),Rs.15300No Cost ,4.2
#
# Product:Samsung Galaxy A20s (Green, 64 GB)
# price:₹13,999₹14,9006% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.4
# Samsung Galaxy A20s (Green| 64 GB),Rs.13999,4.4
#
# Product:Samsung Galaxy A20s (Green, 32 GB)
# price:₹11,999₹12,9006% offNo Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.5
# Samsung Galaxy A20s (Green| 32 GB),Rs.11999,4.5
#
# Product:Samsung Galaxy A10s (Blue, 32 GB)
# price:₹10,499₹11,0004% offUpto ₹9,250 Off on Exchange
# ratings:4.5
# Samsung Galaxy A10s (Blue| 32 GB),Rs.10499,4.5
#
# Product:Samsung Galaxy J7 Nxt (Black, 16 GB)
# price:₹10,990No Cost EMIUpto ₹10,800 Off on Exchange
# ratings:4.4
# Samsung Galaxy J7 Nxt (Black| 16 GB),Rs.10990No Cost ,4.4
